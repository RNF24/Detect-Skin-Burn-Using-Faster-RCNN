# %% [markdown]
# <a href="https://colab.research.google.com/github/RNF24/Detect-Skin-Burn-Using-Faster-RCNN/blob/main/Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#First, clone the repository
# !git clone https://github.com/sovit-123/fastercnn-pytorch-training-pipeline.git
# Out:
# Cloning into 'fastercnn-pytorch-training-pipeline'...
# remote: Enumerating objects: 1327, done.
# remote: Counting objects: 100% (424/424), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 1327 (delta 319), reused 317 (delta 282), pack-reused 903
# Receiving objects: 100% (1327/1327), 12.82 MiB | 14.41 MiB/s, done.
# Resolving deltas: 100% (901/901), done.

# %%
# Install the Requirements
# !pip install -r '/content/fastercnn-pytorch-training-pipeline/requirements.txt' --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 79.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 92.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 53.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 48.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 12.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Dataset
#
# The dataset I used is a public Dataset from RoboFlow.
# Link: https://universe.roboflow.com/aibuildersclub/skin-burns-4yoo2/dataset/3/download

# %%
# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("aibuildersclub").project("skin-burns-4yoo2")
dataset = project.version(3).download("voc")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 20.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# ...

# %%
# %%writefile Skin-Burns--3/custom_data.yaml
# # Images and labels direcotry should be relative to train.py
# TRAIN_DIR_IMAGES: '/content/Skin-Burns--3/train'
# TRAIN_DIR_LABELS: '/content/Skin-Burns--3/train'
# VALID_DIR_IMAGES: '/content/Skin-Burns--3/valid'
# VALID_DIR_LABELS: '/content/Skin-Burns--3/valid'
#
# # Class names.
# CLASSES: [
#     '__background__',
#     '0',
#     '1',
#     '2'
# ]
#
# # Number of classes (object classes + 1 for background class in Faster RCNN).
# NC: 4
#
# # Whether to save the predictions of the validation set while training.
# SAVE_VALID_PREDICTION_IMAGES: True
# Out:
# Writing Skin-Burns--3/custom_data.yaml

# %% [markdown]
# #Train the model
#
# Here we're using Faster R-CNN model with a ResNet-50 backbone and FPN (Feature Pyramid Network) as its base architecture.

# %%
# !python /content/fastercnn-pytorch-training-pipeline/train.py --data /content/Skin-Burns--3/custom_data.yaml --epochs 5 --model fasterrcnn_resnet50_fpn_v2 --name training_FasterRCNN --batch 8
# Out:
# 2023-12-17 08:25:48.272875: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 08:25:48.272933: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 08:25:48.274318: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 08:25:49.411081: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Not using distributed mode
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# ...
